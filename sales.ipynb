# %%
import pandas as pd

# %%
data=pd.read_csv('Sales.csv')

# %%
data
# Out:
#        Sales_Key     Order_ID  Order_Date  Date_Key  Customer_Key  \
# 0              1  ORD00000001  2025-10-30  20251030          1630
# 1              2  ORD00000002  2025-01-06  20250106          2878
# 2              3  ORD00000003  2025-07-08  20250708          3261
# 3              4  ORD00000004  2025-03-20  20250320          3038
# 4              5  ORD00000005  2025-05-22  20250522          1460
# ...          ...          ...         ...       ...           ...
# 49995      49996  ORD00049996  2025-06-26  20250626          4712
# 49996      49997  ORD00049997  2025-12-22  20251222          2826
# 49997      49998  ORD00049998  2025-01-08  20250108          1211
# 49998      49999  ORD00049999  2025-05-22  20250522          1971
# 49999      50000  ORD00050000  2025-12-28  20251228          2737
#
#        Product_Key  Quantity  Unit_Price  Sales_Amount  Discount_Amount  \
# 0              437         1     2295.03       1525.23           769.80
# ...
